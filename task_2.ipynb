# %% [markdown]
# <a href="https://colab.research.google.com/github/KBharath03/PRODIGY_DS_02/blob/main/task_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loadind the dataset.

# %%
df = pd.read_csv('gender_submission.csv')

# %% [markdown]
# Displaying basic information about the dataset

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
# dtypes: int64(2)
# memory usage: 6.7 KB
# None

# %% [markdown]
# Handling missing values

# %%
df = df.dropna()

# %% [markdown]
# Exploratory Data Analysis (EDA)
#
# Descriptive statistics

# %%
print(df.describe())
# Out:
#        PassengerId    Survived
# count   418.000000  418.000000
# mean   1100.500000    0.363636
# std     120.810458    0.481622
# min     892.000000    0.000000
# 25%     996.250000    0.000000
# 50%    1100.500000    0.000000
# 75%    1204.750000    1.000000
# max    1309.000000    1.000000

# %% [markdown]
# Visualizing relationships between variables using pair plot

# %%
sns.pairplot(df)
plt.show()

# %% [markdown]
# Exploring the distribution of the 'Survived' variable

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Survived', data=df, palette='Set1')
plt.title('Distribution of Survival')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Calculating and displaying the survival rate

# %%
survival_rate = df['Survived'].mean()
print(f"Survival Rate: {survival_rate * 100:.2f}%")
# Out:
# Survival Rate: 36.36%

# %% [markdown]
# Creating a correlation matrix

# %%
correlation_matrix = df.corr()

# %% [markdown]
# Creating a correlation heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()
